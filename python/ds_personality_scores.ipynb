# %%
import pandas as pd
from etl import rough_data, continuous_data_etl, categorical_data_etl

# %%
ds_personality_path = '../Resources/personality.csv'
continuous_data_etl(rough_data(ds_personality_path), input_type='df')
# Out:
#     attribute_value  function_1_value  function_2_value  lifestyle_value
# 0                -3                56                19               28
# 1               -75                41                -3               34
# 2               -78                19               -31                6
# 3               -38                28                19               12
# 4                 6                 3                31              -22
# 5               -44                 7               -56               47
# 6               -31                44               -34               -3
# 7               -50                38               -78               25
# 8               -53                38                19               28
# 9               -28                44                -6               -6
# 10                1                 6               -47               -9
# 11              -66                66               -28               41
# ...

# %%
country_personality_path = '../Resources/country-data.csv'
categorical_data_etl(rough_data(ds_personality_path), country_personality_path, input_type='df')
# Out:
#    personality_type     class     usa      chi2
# 0              ESTJ  0.000000  0.0380  0.038000
# 1              ESTP  0.025641  0.0232  0.000257
# 2              ESFJ  0.025641  0.0831  0.039730
# 3              ESFP  0.000000  0.0479  0.047900
# 4              ENTJ  0.051282  0.0257  0.025465
# 5              ENTP  0.051282  0.0469  0.000409
# 6              ENFJ  0.076923  0.0710  0.000494
# 7              ENFP  0.076923  0.1347  0.024782
# 8              ISTJ  0.102564  0.0356  0.125960
# 9              ISTP  0.000000  0.0225  0.022500
# 10             ISFJ  0.000000  0.0758  0.075800
# 11             ISFP  0.025641  0.0515  0.012984
# 12             INTJ  0.307692  0.0326  2.321343
# 13             INTP  0.102564  0.0573  0.035756
# 14             INFJ  0.153846  0.0755  0.081300
# 15             INFP  0.000000  0.1507  0.150700
