# %%
import pandas as pd
from etl import rough_data, continuous_data_etl, categorical_data_etl

# %%
ds_personality_path = '../Resources/personality.csv'
continuous_data_etl(rough_data(ds_personality_path), input_type='df')
# Out:
#     attribute_value  function_1_value  function_2_value  lifestyle_value
# 0                -3                56                19               28
# 1               -75                41                -3               34
# 2               -78                19               -31                6
# 3               -38                28                19               12
# 4                 6                 3                31              -22
# 5               -44                 7               -56               47
# 6               -31                44               -34               -3
# 7               -50                38               -78               25
# 8               -53                38                19               28
# 9               -28                44                -6               -6
# 10                1                 6               -47               -9
# 11              -66                66               -28               41
# 12              -34                12               -25               31
# 13                9               -16                -9              -25
# 14              -31                16               -78               62
# 15               75                22                 3              -12
# 16               59                53                -1              -19
# 17              -38                16               -25               -6
# 18              -19                -9                50               -9
# 19              -31                19               -19               22
# 20                1               -12                25                9
# 21              -56                -9                -6               34
# 22               16                47                41               25
# 23              -25                25                25               16
# 24                6                 9                 6               -3
# 25               19                22                -6               22
# 26              -53                44                -3              -47
# 27              -59                31                 9               38
# 28               22                 6                12               22
# 29               19                 3                19                1
# 30              -59                62               -53                9
# 31              -28                 3               -53               22
# 32              -30                -1               -26               15
# 33              -22                19                -1                6
# 34              -47               -25                -1               34
# 35              -59                -6               -38                3
# 36               62                 9               -12               66
# 37              -44                 9                 6               19
# 38               -9                12               -41               16

# %%
country_personality_path = '../Resources/country-data.csv'
categorical_data_etl(rough_data(ds_personality_path), country_personality_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'attribute'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 country_personality_path = '../Resources/country-data.csv'
# ----> 2 categorical_data_etl(ds_personality_path, country_personality_path)
#
# File ~\OneDrive\Desktop\Data_Science\Other_Repos\DS-Personality-Scores\python\etl.py:32, in categorical_data_etl(input1_path, input2_path, output_path, type)
#      29 pts = ['ESTJ', 'ESTP', 'ESFJ', 'ESFP', 'ENTJ', 'ENTP', 'ENFJ', 'ENFP', 'ISTJ', 'ISTP', 'ISFJ', 'ISFP', 'INTJ', 'INTP', 'INFJ', 'INFP']
#      31 df1 = pd.read_csv(input1_path)
# ---> 32 df1['type'] = df1['attribute']+df1['function 1']+df1['function 2']+df1['lifestyle']
#      33 pt1 = [df1.loc[df1['type']==pt, 'type'].count()/100 for pt in pts]
#      35 df2 = pd.read_csv(input2_path)
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'attribute'
